# %% [markdown]
# #Objective
# This notebook focuses on cleaning and uniting cpu, and gpu names into shared groups, example: i3, i4, amd ... ect

# %%
import pandas as pd

df = pd.read_csv("full_merged_dataset.csv")

# Define file paths
FILE_PATH = 'full_merged_dataset_copy.csv'
OUTPUT_PATH = 'cleaned_dataset_leena.csv'

# %% [markdown]
# #1- Load Data
#
# we first load our data:

# %%
df = pd.read_csv("full_merged_dataset.csv")

print(df.head())
# Out:
#         PRICE LAPTOP_CONDITION    LAPTOP_BRAND    LAPTOP_MODEL  \
# 0  75000000.0          BON TAT  NeedToBeFilled         IDEAPAD
# 1  33500000.0    JAMAIS UTILIS  NeedToBeFilled            AERO
# 2  17000000.0   NeedToBeFilled  NeedToBeFilled         STEALTH
# 3  12000000.0   NeedToBeFilled  NeedToBeFilled             ROG
# 4  11000000.0          BON TAT  NeedToBeFilled  NeedToBeFilled
#
#              DEDICATED_GPU     GPU_GENERAL  GPU_INTEGRATED  \
# 0           NeedToBeFilled  NeedToBeFilled  NeedToBeFilled
# 1  NVIDIA GEFORCE RTX 3060  NeedToBeFilled  NeedToBeFilled
# 2  NVIDIA GEFORCE GTX 1060  NeedToBeFilled  NeedToBeFilled
# 3  NVIDIA GEFORCE RTX 1650  NeedToBeFilled  NeedToBeFilled
# 4        AMD RADEON RX 580  NeedToBeFilled  NeedToBeFilled
#
#                              CPU RAM_SIZE        RAM_TYPE        SSD_SIZE  \
# 0             INTEL CORE I5 750S      4GB  NeedToBeFilled           128GB
# 1  11TH GEN INTEL CORE I7 11800H     16GB  NeedToBeFilled             1TB
# 2           INTEL CORE I7 7700HQ     16GB  NeedToBeFilled  NeedToBeFilled
# 3             AMD RYZEN 7 5800HS     16GB  NeedToBeFilled           512GB
# 4              AMD RYZEN 5 2400G     16GB  NeedToBeFilled           128GB
#
#          HDD_SIZE    STORAGE_SIZE    STORAGE_TYPE     SCREEN_SIZE  \
# 0  NeedToBeFilled  NeedToBeFilled  NeedToBeFilled            14.0
# 1  NeedToBeFilled  NeedToBeFilled  NeedToBeFilled            15.6
# 2  NeedToBeFilled  NeedToBeFilled  NeedToBeFilled            17.3
# 3  NeedToBeFilled  NeedToBeFilled  NeedToBeFilled            14.0
# 4           145GB  NeedToBeFilled  NeedToBeFilled  NeedToBeFilled
#
#   SCREEN_FREQUENCY SCREEN_RESOLUTION        CITY  POST_YEAR  POST_MONTH
# 0   NeedToBeFilled    NeedToBeFilled    EL TAREF       2021          10
# 1   NeedToBeFilled         3840x2160       COLLO       2021          11
# 2            120Hz    NeedToBeFilled    MECHERIA       2021           9
# 3   NeedToBeFilled    NeedToBeFilled    ES SENIA       2025           3
# 4             60Hz    NeedToBeFilled  TIZI OUZOU       2024          10

# %% [markdown]
# #2- Clean CPU names
#
# We will first start with the CPU, for which we will group them to the following: intel core, i3, i4, ..., i9 , amd, and ryzen:

# %%
df["CPU"] = df["CPU"].fillna("none")
df["CPU"].unique()


df["CPU"] = (
    df["CPU"]
      .str.lower()
      .str.replace(r"\s+", " ", regex=True)
      .str.strip()
)

for i in range(1, 10):  # i1 through i9
    df["CPU"] = df["CPU"].str.replace(
        rf".*i{i}.*",  # notice the `f` after `r` → raw f-string
        f"i{i}",
        case=False,
        regex=True
    )

for i in range(1, 3):  # i1 through i9
    df["CPU"] = df["CPU"].str.replace(
        rf".*m{i}.*",  # notice the `f` after `r` → raw f-string
        f"apple",
        case=False,
        regex=True
    )


df["CPU"] = df["CPU"].str.replace(
    r".*amd.*",
    "AMD",
    case=False,
    regex=True
)

df["CPU"] = df["CPU"].str.replace(
    r".*ryzen.*",
    "RYZEN",
    case=False,
    regex=True
)

df["CPU"] = df["CPU"].str.replace(
    r".*core.*",
    "intel core",
    case=False,
    regex=True
)

counts = df["CPU"].value_counts()

df["CPU"] = df["CPU"].where(
    df["CPU"].map(counts) > 100,
    "other"
)

df = df[df["CPU"].str.lower() != "none"]

df["CPU"] = (
    df["CPU"]
      .str.lower()
      .str.replace(r"\s+", " ", regex=True)
      .str.strip()
)

print(df["CPU"].unique())

df["CPU"].value_counts()
# Out:
# ['i5' 'i7' 'amd' ... 'intel 15 11300' 'cpu 2.20 ghz 2.20 ghz' 'ddr2']
# ['i5' 'i7' 'amd' 'i3' 'i9' 'apple' 'intel celeron' 'other' 'intel core'
#  'apple m4' 'apple m3' 'intel celeron n4020' 'ryzen']
# CPU
# i5                     19545
# i7                     12267
# amd                     4877
# other                   2897
# i3                      2885
# apple                   1876
# intel core              1744
# i9                      1321
# ryzen                    527
# apple m3                 325
# apple m4                 160
# intel celeron n4020      147
# intel celeron            105
# Name: count, dtype: int64

# %% [markdown]
# #3- Cleaning the GPU_INTEGRATED Column
#
# First we are renaming the values to not have only english characters:

# %%
df["GPU_GENERAL"] = df["GPU_GENERAL"].fillna("Unknown")
df["GPU_GENERAL"].head()

translation_map = {
    "Integrée": "Integrated",
    "Dédiée": "Dedicated",
    "Integrée + Dédiée": "Integrated + Dedicated",
    'Intégrée' : "Integrated"
}

df["GPU_GENERAL"] = df["GPU_GENERAL"].replace(translation_map)

df["GPU_GENERAL"].unique()
# Out:
# array(['NeedToBeFilled', 'Integrated + Dedicated', 'Integrated',
#        'Dedicated'], dtype=object)

# %% [markdown]
# #4- Cleaning the DEDICATED_GPU Column
#
# Here we do the same thing we did for the CPUs, we group them to 4 major bins: Nvidia, AMD, apple, other, none

# %%
df["DEDICATED_GPU"].unique()

df["DEDICATED_GPU"] = (
    df["DEDICATED_GPU"]
      .str.lower()
      .str.replace(r"\s+", " ", regex=True)
      .str.strip()
)

df["DEDICATED_GPU"] = df["DEDICATED_GPU"].str.replace( #getting renamed to apple for some reason
    r".*NeedToBeFilled.*",
    "None",
    case=False,
    regex=True
)

df["DEDICATED_GPU"] = df["DEDICATED_GPU"].str.replace(
    r".*nvidia.*",
    "Nvidia",
    case=False,
    regex=True
)

df["DEDICATED_GPU"] = df["DEDICATED_GPU"].str.replace(
    r".*amd.*",
    "AMD",
    case=False,
    regex=True
)

df["DEDICATED_GPU"] = df["DEDICATED_GPU"].str.replace(
    r".*apple.*",
    "Apple",
    case=False,
    regex=True
)



counts = df["DEDICATED_GPU"].value_counts()

df["DEDICATED_GPU"] = df["DEDICATED_GPU"].where(
    df["DEDICATED_GPU"].map(counts) > 50,
    "other"
)

df["DEDICATED_GPU"].unique()

df["DEDICATED_GPU"].value_counts()
# Out:
# DEDICATED_GPU
# Apple     38509
# Nvidia     8233
# other      1124
# AMD         810
# Name: count, dtype: int64

# %% [markdown]
# #5- Cleaning GPU_INTEGRATED Column
# Same as the previous, however this one we only focus on intel, amd and apple since they are the dominant force here:

# %%
df["GPU_INTEGRATED"].unique()

df["GPU_INTEGRATED"] = (
    df["GPU_INTEGRATED"]
      .str.lower()
      .str.replace(r"\s+", " ", regex=True)
      .str.strip()
)

df["GPU_INTEGRATED"] = df["GPU_INTEGRATED"].str.replace(
    r".*intel.*",
    "Intel",
    case=False,
    regex=True
)

df["GPU_INTEGRATED"] = df["GPU_INTEGRATED"].str.replace(
    r".*amd.*",
    "AMD",
    case=False,
    regex=True
)

df["GPU_INTEGRATED"] = df["GPU_INTEGRATED"].str.replace(
    r".*apple.*",
    "Apple",
    case=False,
    regex=True
)

df["GPU_INTEGRATED"] = df["GPU_INTEGRATED"].str.replace(
    r".*NeedToBeFilled.*",
    "None",
    case=False,
    regex=True
)


counts = df["GPU_INTEGRATED"].value_counts()

df["GPU_INTEGRATED"] = df["GPU_INTEGRATED"].where(
    df["GPU_INTEGRATED"].map(counts) > 200,
    "other"
)

df["GPU_INTEGRATED"].unique()

df["GPU_INTEGRATED"].value_counts()
# Out:
# GPU_INTEGRATED
# none     37621
# other     5074
# Intel     4607
# AMD       1145
# Apple      229
# Name: count, dtype: int64

# %% [markdown]
# #6- Resolving Contradictions:
# This section is to find/resolve Contradicions between the CPU/GPU_INTEGRATED/DEDICATED_GPU and GPU_INTEGRATED:

# %%
contradictions = df[
    ((df["GPU_INTEGRATED"] != "None") & (df["GPU_GENERAL"] == "Dedicated")) |
    ((df["GPU_INTEGRATED"] == "None") & (df["GPU_GENERAL"] == "Integrated")) |
    ((df["DEDICATED_GPU"] == "None") & df["GPU_GENERAL"].str.contains("Dedicated")) |
    ((df["DEDICATED_GPU"] != "None") & (df["GPU_GENERAL"] == "Integrated"))
]

print(contradictions)

# not working as intended
# Out:
#           PRICE     LAPTOP_CONDITION    LAPTOP_BRAND    LAPTOP_MODEL  \
# 16408  115000.0            Etat neuf            DELL  NeedToBeFilled
# 16410      -1.0            Etat neuf              Hp  NeedToBeFilled
# 16411  117000.0             Bon état  NeedToBeFilled  NeedToBeFilled
# 16412   59000.0           Etat moyen            DELL  NeedToBeFilled
# 16414   70000.0            Etat neuf           Intel  NeedToBeFilled
# ...         ...                  ...             ...             ...
# 37217       1.0             Bon état  NeedToBeFilled  NeedToBeFilled
# 37219      -1.0             Bon état     Razer Blade  NeedToBeFilled
# 37220  171500.0  Neuf jamais utilisé              HP  NeedToBeFilled
# 37221   30000.0             Bon état         Apples🍎  NeedToBeFilled
# 37223  249000.0            Etat neuf           APPLE  NeedToBeFilled
#
#       DEDICATED_GPU GPU_GENERAL GPU_INTEGRATED    CPU RAM_SIZE  \
# 16408         Apple  Integrated          Intel     i5    16 GO
# 16410         Apple  Integrated          other     i5     8 GO
# 16411         Apple  Integrated          other     i7    32 GO
# 16412         Apple  Integrated          Intel     i5     8 GO
# 16414         Apple  Integrated          other     i7    16 GO
# ...             ...         ...            ...    ...      ...
# 37217         Apple  Integrated          other     i5     8 GO
# 37219        Nvidia  Integrated          Intel     i7    16 GO
# 37220         Apple  Integrated          other     i5     8 GO
# 37221         Apple  Integrated           none     i5     4 GO
# 37223         Apple  Integrated          other  apple    16 GO
#
#              RAM_TYPE        SSD_SIZE        HDD_SIZE STORAGE_SIZE  \
# 16408  NeedToBeFilled  NeedToBeFilled  NeedToBeFilled        512GO
# 16410  NeedToBeFilled  NeedToBeFilled  NeedToBeFilled        256GO
# 16411  NeedToBeFilled  NeedToBeFilled  NeedToBeFilled        512GO
# 16412  NeedToBeFilled  NeedToBeFilled  NeedToBeFilled        256GO
# 16414  NeedToBeFilled  NeedToBeFilled  NeedToBeFilled        256GO
# ...               ...             ...             ...          ...
# 37217  NeedToBeFilled  NeedToBeFilled  NeedToBeFilled        237GO
# 37219  NeedToBeFilled  NeedToBeFilled  NeedToBeFilled        512GO
# 37220  NeedToBeFilled  NeedToBeFilled  NeedToBeFilled        512GO
# 37221  NeedToBeFilled  NeedToBeFilled  NeedToBeFilled        256GO
# 37223  NeedToBeFilled  NeedToBeFilled  NeedToBeFilled        512GO
#
#       STORAGE_TYPE     SCREEN_SIZE SCREEN_FREQUENCY SCREEN_RESOLUTION  \
# 16408          SSD            14"    NeedToBeFilled    NeedToBeFilled
# 16410          SSD            14"    NeedToBeFilled    NeedToBeFilled
# 16411          SSD            14"    NeedToBeFilled    NeedToBeFilled
# 16412          SSD            13"    NeedToBeFilled    NeedToBeFilled
# 16414          SSD          13.3"    NeedToBeFilled    NeedToBeFilled
# ...            ...             ...              ...               ...
# 37217          SSD  NeedToBeFilled   NeedToBeFilled    NeedToBeFilled
# 37219          SSD            15"    NeedToBeFilled    NeedToBeFilled
# 37220          SSD            16"    NeedToBeFilled    NeedToBeFilled
# 37221          SSD            13"    NeedToBeFilled    NeedToBeFilled
# 37223          SSD            16"    NeedToBeFilled    NeedToBeFilled
#
#                CITY  POST_YEAR  POST_MONTH
# 16408   Bab ezzouar         -1          -1
# 16410   Bab ezzouar         -1          -1
# 16411   Bab ezzouar         -1          -1
# 16412   Bab ezzouar         -1          -1
# 16414   Bab ezzouar         -1          -1
# ...             ...        ...         ...
# 37217   Sidi moussa         -1          -1
# 37219   Bab ezzouar         -1          -1
# 37220  Alger centre         -1          -1
# 37221          Oran         -1          -1
# 37223    Mostaganem         -1          -1
#
# [10980 rows x 20 columns]

# %% [markdown]
# #7- Export Output:
# Exporting output:

# %%
df.sample(20)
# Out:
#           PRICE     LAPTOP_CONDITION        LAPTOP_BRAND    LAPTOP_MODEL  \
# 5313   128000.0        JAMAIS UTILIS      NeedToBeFilled          GALAXY
# 32880  135000.0  Neuf jamais utilisé                  Hp  NeedToBeFilled
# 38963  129000.0     Never Used (New)                  LG  NeedToBeFilled
# 14256   41000.0              BON TAT      NeedToBeFilled            SPIN
# 20622   52000.0            Etat neuf          HP PROBOOK  NeedToBeFilled
# 8961    85000.0       NeedToBeFilled      NeedToBeFilled            YOGA
# 37807  460000.0     Never Used (New)               APPLE     MACBOOK PRO
# 37786  490000.0     Never Used (New)               APPLE     MACBOOK PRO
# 20471  279000.0            Etat neuf  HP ZBOOK POWER G10  NeedToBeFilled
# 39547  134000.0     Never Used (New)                DELL        LATITUDE
# 41192   45000.0       Good Condition                  HP       ELITEBOOK
# 27435   90000.0           Etat moyen        macOS Sierra  NeedToBeFilled
# 47276   35800.0       NeedToBeFilled              LENOVO        THINKPAD
# 33345   52000.0             Bon état                DELL  NeedToBeFilled
# 51723   12000.0       Good Condition                ASUS        VIVOBOOK
# 51831  271200.0       NeedToBeFilled                  HP            OMEN
# 22523   85000.0            Etat neuf               INTEL  NeedToBeFilled
# 9712    79000.0        JAMAIS UTILIS      NeedToBeFilled       ELITEBOOK
# 37113   45000.0            Etat neuf      NeedToBeFilled  NeedToBeFilled
# 17053   53000.0             Bon état                DELL  NeedToBeFilled
#
#       DEDICATED_GPU             GPU_GENERAL GPU_INTEGRATED    CPU RAM_SIZE  \
# 5313          Apple          NeedToBeFilled           none     i5      8GB
# 32880         Apple              Integrated            AMD    amd    16 GO
# 38963         Apple          NeedToBeFilled           none     i7     32GB
# 14256         Apple          NeedToBeFilled           none     i3      8GB
# 20622         Apple              Integrated          Intel     i5     8 GO
# 8961          Apple          NeedToBeFilled           none     i5     16GB
# 37807         Apple          NeedToBeFilled           none  other     32GB
# 37786         Apple          NeedToBeFilled           none  other     24GB
# 20471        Nvidia  Integrated + Dedicated          other     i7    32 GO
# 39547         Apple          NeedToBeFilled           none     i7     32GB
# 41192         Apple          NeedToBeFilled           none     i5      8GB
# 27435         Apple          NeedToBeFilled           none     i5     8 GO
# 47276         Apple          NeedToBeFilled           none     i5      8GB
# 33345         Apple              Integrated          Intel     i5     8 GO
# 51723        Nvidia          NeedToBeFilled           none     i7     16GB
# 51831        Nvidia          NeedToBeFilled           none     i9     16GB
# 22523         Apple              Integrated          Intel     i5    16 GO
# 9712          Apple          NeedToBeFilled           none     i5     16GB
# 37113         Apple              Integrated           none  other     8 GO
# 17053         Apple              Integrated          other     i5     8 GO
#
#              RAM_TYPE        SSD_SIZE        HDD_SIZE    STORAGE_SIZE  \
# 5313            DDR4X           256GB  NeedToBeFilled  NeedToBeFilled
# 32880  NeedToBeFilled  NeedToBeFilled  NeedToBeFilled          1000GO
# 38963  NeedToBeFilled          1000GB  NeedToBeFilled  NeedToBeFilled
# 14256  NeedToBeFilled           128GB  NeedToBeFilled  NeedToBeFilled
# 20622  NeedToBeFilled  NeedToBeFilled  NeedToBeFilled           128GO
# 8961   NeedToBeFilled           512GB  NeedToBeFilled  NeedToBeFilled
# 37807           DDR5X          1000GB  NeedToBeFilled  NeedToBeFilled
# 37786            DDR5           512GB  NeedToBeFilled  NeedToBeFilled
# 20471  NeedToBeFilled  NeedToBeFilled  NeedToBeFilled          1024GO
# 39547            DDR5           512GB  NeedToBeFilled  NeedToBeFilled
# 41192  NeedToBeFilled           256GB  NeedToBeFilled  NeedToBeFilled
# 27435  NeedToBeFilled  NeedToBeFilled  NeedToBeFilled           320GO
# 47276  NeedToBeFilled           128GB  NeedToBeFilled  NeedToBeFilled
# 33345  NeedToBeFilled  NeedToBeFilled  NeedToBeFilled           256GO
# 51723  NeedToBeFilled          1000GB           750GB  NeedToBeFilled
# 51831  NeedToBeFilled          1000GB  NeedToBeFilled  NeedToBeFilled
# 22523  NeedToBeFilled  NeedToBeFilled  NeedToBeFilled           256GO
# 9712            DDR4X           256GB  NeedToBeFilled  NeedToBeFilled
# 37113  NeedToBeFilled  NeedToBeFilled  NeedToBeFilled           512GO
# 17053  NeedToBeFilled  NeedToBeFilled  NeedToBeFilled           256GO
#
#          STORAGE_TYPE SCREEN_SIZE SCREEN_FREQUENCY SCREEN_RESOLUTION  \
# 5313   NeedToBeFilled        13.3   NeedToBeFilled         1920x1080
# 32880             SSD      17.3"    NeedToBeFilled    NeedToBeFilled
# 38963  NeedToBeFilled        17.0   NeedToBeFilled               QHD
# 14256  NeedToBeFilled        14.0   NeedToBeFilled    NeedToBeFilled
# 20622             SSD        12"    NeedToBeFilled    NeedToBeFilled
# 8961   NeedToBeFilled        14.0   NeedToBeFilled    NeedToBeFilled
# 37807  NeedToBeFilled        14.0   NeedToBeFilled    NeedToBeFilled
# 37786  NeedToBeFilled        14.0   NeedToBeFilled                3K
# 20471             SSD        16"    NeedToBeFilled    NeedToBeFilled
# 39547  NeedToBeFilled        14.0   NeedToBeFilled               FHD
# 41192  NeedToBeFilled        13.0   NeedToBeFilled    NeedToBeFilled
# 27435           Autre   16" - 17"   NeedToBeFilled    NeedToBeFilled
# 47276  NeedToBeFilled        12.5   NeedToBeFilled                HD
# 33345             SSD        14"    NeedToBeFilled    NeedToBeFilled
# 51723  NeedToBeFilled        17.0   NeedToBeFilled    NeedToBeFilled
# 51831  NeedToBeFilled        16.0   NeedToBeFilled               QHD
# 22523             SSD      13.3"    NeedToBeFilled    NeedToBeFilled
# 9712   NeedToBeFilled        13.3   NeedToBeFilled         1920x1080
# 37113             SSD        14"    NeedToBeFilled    NeedToBeFilled
# 17053             SSD        14"    NeedToBeFilled    NeedToBeFilled
#
#                  CITY  POST_YEAR  POST_MONTH
# 5313     ALGER CENTRE       2024           9
# 32880       Boumerdes         -1          -1
# 38963  NeedToBeFilled       2025           7
# 14256     OULED FAYET       2025           6
# 20622    Alger centre         -1          -1
# 8961           ANNABA       2025           6
# 37807  NeedToBeFilled       2024          10
# 37786  NeedToBeFilled       2025           7
# 20471     Bab ezzouar         -1          -1
# 39547  NeedToBeFilled       2025           7
# 41192  NeedToBeFilled       2024          12
# 27435          Draria         -1          -1
# 47276  NeedToBeFilled       2025           7
# 33345      Ain naadja         -1          -1
# 51723  NeedToBeFilled       2021           8
# 51831  NeedToBeFilled       2025           6
# 22523     Bab ezzouar         -1          -1
# 9712     ALGER CENTRE       2024          10
# 37113          Bouira         -1          -1
# 17053           Kouba         -1          -1
